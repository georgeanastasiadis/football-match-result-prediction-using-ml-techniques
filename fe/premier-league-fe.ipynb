# %%
import pandas as pd
import numpy as np

# %%
s1415 = pd.read_csv(r'C:\Users\George\Desktop\football-match-prediction-using-ml-techniques\data\Premier League\epl-1415.csv')
s1516 = pd.read_csv(r'C:\Users\George\Desktop\football-match-prediction-using-ml-techniques\data\Premier League\epl-1516.csv')
s1617 = pd.read_csv(r'C:\Users\George\Desktop\football-match-prediction-using-ml-techniques\data\Premier League\epl-1617.csv')
s1718 = pd.read_csv(r'C:\Users\George\Desktop\football-match-prediction-using-ml-techniques\data\Premier League\epl-1718.csv')
s1819 = pd.read_csv(r'C:\Users\George\Desktop\football-match-prediction-using-ml-techniques\data\Premier League\epl-1819.csv')
s1920 = pd.read_csv(r'C:\Users\George\Desktop\football-match-prediction-using-ml-techniques\data\Premier League\epl-1920.csv')

# %%
def w_d_a(df):
    
    df['HTW'] = np.where(df['FTR']=='H',1,0)
    df['HTD'] = np.where(df['FTR']=='D',1,0) 
    df['HTL'] = np.where(df['FTR']=='A',1,0)
    
    df['ATL'] = np.where(df['FTR']=='H',1,0)
    df['ATD'] = np.where(df['FTR']=='D',1,0) 
    df['ATW'] = np.where(df['FTR']=='A',1,0)
    
    return df

# %%
s1415 = w_d_a(s1415)
s1516 = w_d_a(s1516)
s1617 = w_d_a(s1617)
s1718 = w_d_a(s1718)
s1819 = w_d_a(s1819)
s1920 = w_d_a(s1920)

# %%
#number of team's wins
def total_t_wins(df):
    
    #Dataframe of home team matches
    home_df = df.groupby(['Date','HomeTeam']).sum()['HTW'].reset_index()
    home_df.columns = ['Date','Team','W']
    
    #Dataframe of away team matches
    away_df = df.groupby(['Date','AwayTeam']).sum()['ATW'].reset_index()
    away_df.columns = ['Date','Team','W']
    
    #Concatenation of the two dataframes and then we sort it by date ascending
    cdf = pd.concat([home_df,away_df],ignore_index=True)
    cdf = cdf.sort_values('Date',ascending=True)

    #camulative summation of the number of wins
    cdf['Wins'] = cdf.groupby('Team')['W'].apply(lambda x: x.shift().cumsum())
    
    #creation of the two columns
    df = pd.merge(df,cdf,how='inner',left_on=['Date','HomeTeam'],right_on=['Date','Team'])
    df.rename(columns={'Wins':'HT_wins'},inplace=True)
    df = df.drop(['Team','W'],axis=1)
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','AwayTeam'],right_on=['Date','Team'])
    df.rename(columns={'Wins':'AT_wins'},inplace=True)
    df = df.drop(['Team','W'],axis=1)


    return df

# %%
s1415 = total_t_wins(s1415)
s1516 = total_t_wins(s1516)
s1617 = total_t_wins(s1617)
s1718 = total_t_wins(s1718)
s1819 = total_t_wins(s1819)
s1920 = total_t_wins(s1920)

# %%
#number of team's draws
def total_t_draws(df):
    
    #Dataframe of home team matches
    home_df = df.groupby(['Date','HomeTeam']).sum()['HTD'].reset_index()
    home_df.columns = ['Date','Team','D']
    
    #Dataframe of away team matches
    away_df = df.groupby(['Date','AwayTeam']).sum()['ATD'].reset_index()
    away_df.columns = ['Date','Team','D']
    
    #Concatenation of the two dataframes and then we sort it by date ascending
    cdf = pd.concat([home_df,away_df],ignore_index=True)
    cdf = cdf.sort_values('Date',ascending=True)

     #camulative summation of the number of draws
    cdf['Draws'] = cdf.groupby('Team')['D'].apply(lambda x: x.shift().cumsum())
    
    #creation of the two columns
    df = pd.merge(df,cdf,how='inner',left_on=['Date','HomeTeam'],right_on=['Date','Team'])
    df.rename(columns={'Draws':'HT_draws'},inplace=True)
    df = df.drop(['Team','D'],axis=1)
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','AwayTeam'],right_on=['Date','Team'])
    df.rename(columns={'Draws':'AT_draws'},inplace=True)
    df = df.drop(['Team','D'],axis=1)


    return df

# %%
s1415 = total_t_draws(s1415)
s1516 = total_t_draws(s1516)
s1617 = total_t_draws(s1617)
s1718 = total_t_draws(s1718)
s1819 = total_t_draws(s1819)
s1920 = total_t_draws(s1920)

# %%
#number of team's losses
def total_t_losses(df):
    
    #Dataframe of home team matches
    home_df = df.groupby(['Date','HomeTeam']).sum()['HTL'].reset_index()
    home_df.columns = ['Date','Team','L']
    
    #Dataframe of away team matches
    away_df = df.groupby(['Date','AwayTeam']).sum()['ATL'].reset_index()
    away_df.columns = ['Date','Team','L']
    
    #Concatenation of the two dataframes and then we sort it by date ascending
    cdf = pd.concat([home_df,away_df],ignore_index=True)
    cdf = cdf.sort_values('Date',ascending=True)

    #camulative summation of the number of losses
    cdf['Losses'] = cdf.groupby('Team')['L'].apply(lambda x: x.shift().cumsum())
    
    #creation of the two columns
    df = pd.merge(df,cdf,how='inner',left_on=['Date','HomeTeam'],right_on=['Date','Team'])
    df.rename(columns={'Losses':'HT_losses'},inplace=True)
    df = df.drop(['Team','L'],axis=1)
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','AwayTeam'],right_on=['Date','Team'])
    df.rename(columns={'Losses':'AT_losses'},inplace=True)
    df = df.drop(['Team','L'],axis=1)


    return df

# %%
s1415 = total_t_losses(s1415)
s1516 = total_t_losses(s1516)
s1617 = total_t_losses(s1617)
s1718 = total_t_losses(s1718)
s1819 = total_t_losses(s1819)
s1920 = total_t_losses(s1920)

# %%
#rolling average of shots on target a team makes in a time window of 5 games.
def roll_avg_ST(df):
    
    #Dataframe of home team matches
    home_df = df.groupby(['Date','HomeTeam']).sum()['HST'].reset_index()
    home_df.columns = ['Date','Team','ST']
    
    #Dataframe of away team matches
    away_df = df.groupby(['Date','AwayTeam']).sum()['AST'].reset_index()
    away_df.columns = ['Date','Team','ST']
    
    #Concatenation of the two dataframes and then we sort it by date ascending
    cdf = pd.concat([home_df,away_df],ignore_index=True)
    cdf = cdf.sort_values('Date',ascending=True)

    #calculation of rolling avg for each team
    cdf['ravg_ST'] = cdf.groupby('Team')['ST'].apply(lambda x: x.rolling(window=5, closed='left').mean())
    
    #creation of the two columns
    df = pd.merge(df,cdf,how='inner',left_on=['Date','HomeTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_ST':'l5_ravg_HTST'},inplace=True)
    df = df.drop(['Team','ST'],axis=1)
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','AwayTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_ST':'l5_ravg_ATST'},inplace=True)
    df = df.drop(['Team','ST'],axis=1)


    return df

# %%
s1415 = roll_avg_ST(s1415)
s1516 = roll_avg_ST(s1516)
s1617 = roll_avg_ST(s1617)
s1718 = roll_avg_ST(s1718)
s1819 = roll_avg_ST(s1819)
s1920 = roll_avg_ST(s1920)

# %%
#conversion rate of each team
def team_cr(df):
    
    df['HTCR'] = np.where(df['HST']!=0,round(df['FTHG']/df['HST'],2),0)
    df['ATCR'] = np.where(df['AST']!=0,round(df['FTAG']/df['AST'],2),0)
    
    return df

# %%
s1415 = team_cr(s1415)
s1516 = team_cr(s1516)
s1617 = team_cr(s1617)
s1718 = team_cr(s1718)
s1819 = team_cr(s1819)
s1920 = team_cr(s1920)

# %%
#rolling average of conversion rate that a team has in a time window of 5 games
def roll_avg_CR(df):
    
    #Dataframe of home team
    home_df = df.groupby(['Date','HomeTeam']).sum()['HTCR'].reset_index()
    home_df.columns = ['Date','Team','CR']
    
    #Dataframe of away team 
    away_df = df.groupby(['Date','AwayTeam']).sum()['ATCR'].reset_index()
    away_df.columns = ['Date','Team','CR']
    
    #Concatenation of the two dataframes and then we sort it by date ascending
    CRdf = pd.concat([home_df,away_df],ignore_index=True)
    CRdf = CRdf.sort_values('Date',ascending=True)

    #Calculation of rolling avg for each team
    CRdf['ravg_CR'] = CRdf.groupby('Team')['CR'].apply(lambda x: x.rolling(window=5,closed='left').mean())
    
    #Creation of the Columns
    df = pd.merge(df,CRdf,how='inner',left_on=['Date','HomeTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_CR':'l5_ravg_HTCR'},inplace=True)
    df = df.drop(['Team','CR'],axis=1)
    
    df = pd.merge(df,CRdf,how='inner',left_on=['Date','AwayTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_CR':'l5_ravg_ATCR'},inplace=True)
    df = df.drop(['Team','CR'],axis=1)


    return df

# %%
s1415 = roll_avg_CR(s1415)
s1516 = roll_avg_CR(s1516)
s1617 = roll_avg_CR(s1617)
s1718 = roll_avg_CR(s1718)
s1819 = roll_avg_CR(s1819)
s1920 = roll_avg_CR(s1920)

# %%
#number of goals a team scores during the season
def goal_scored(df):
    teams = {key:[0] for key in df['HomeTeam'].unique()}
    
    for i,row in df.iterrows():
        
        teams[row['HomeTeam']].append(teams[row['HomeTeam']][-1] + row['FTHG'])
        teams[row['AwayTeam']].append(teams[row['AwayTeam']][-1] + row['FTAG'])
        
    df['HTGS'] = 0
    df['ATGS'] = 0
    
    for i, row in df.iterrows():
    
        df.at[i, 'HTGS'] = teams[row['HomeTeam']].pop(0)
        df.at[i, 'ATGS'] = teams[row['AwayTeam']].pop(0)
  
    return df

# %%
s1415 = goal_scored(s1415)
s1516 = goal_scored(s1516)
s1617 = goal_scored(s1617)
s1718 = goal_scored(s1718)
s1819 = goal_scored(s1819)
s1920 = goal_scored(s1920)

# %%
#number of goals a team concedes during the season
def goals_conceded(df):
    teams = {key:[0] for key in df['HomeTeam'].unique()}
    
    for i,row in df.iterrows():
        
        teams[row['HomeTeam']].append(teams[row['HomeTeam']][-1] + row['FTAG'])
        teams[row['AwayTeam']].append(teams[row['AwayTeam']][-1] + row['FTHG'])
        
    df['HTGC'] = 0
    df['ATGC'] = 0
    
    for i, row in df.iterrows():
    
        df.at[i, 'HTGC'] = teams[row['HomeTeam']].pop(0)
        df.at[i, 'ATGC'] = teams[row['AwayTeam']].pop(0)
    
    
    return df

# %%
s1415 = goals_conceded(s1415)
s1516 = goals_conceded(s1516)
s1617 = goals_conceded(s1617)
s1718 = goals_conceded(s1718)
s1819 = goals_conceded(s1819)
s1920 = goals_conceded(s1920)

# %%
#overall stats for each team
def team_overall(df):
    
    df['HToveral'] = df['HTGS'] - df['HTGC']
    df['AToveral'] = df['ATGS'] - df['ATGC']
    
    return df

# %%
s1415 = team_overall(s1415)
s1516 = team_overall(s1516)
s1617 = team_overall(s1617)
s1718 = team_overall(s1718)
s1819 = team_overall(s1819)
s1920 = team_overall(s1920)

# %%
#rolling average of xGoals of each team in a time window of 5 games
def roll_avg_xG(df):
    
    #Dataframe of home team 
    home_df = df.groupby(['Date','HomeTeam']).sum()['HxG'].reset_index()
    home_df.columns = ['Date','Team','xG']
    
    #Dataframe of away team 
    away_df = df.groupby(['Date','AwayTeam']).sum()['AxG'].reset_index()
    away_df.columns = ['Date','Team','xG']
    
    #Concatenation of the two dataframes and then we sort it by date ascending
    cdf = pd.concat([home_df,away_df],ignore_index=True)
    cdf = cdf.sort_values('Date',ascending=True)

    #calculation of rolling avg of xG for each team
    cdf['ravg_xG'] = cdf.groupby('Team')['xG'].apply(lambda x: x.rolling(window=5,closed='left').mean())
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','HomeTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_xG':'l5_ravg_HTxG'},inplace=True)
    df = df.drop(['Team','xG'],axis=1)
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','AwayTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_xG':'l5_ravg_ATxG'},inplace=True)
    df = df.drop(['Team','xG'],axis=1)


    return df

# %%
s1415 = roll_avg_xG(s1415)
s1516 = roll_avg_xG(s1516)
s1617 = roll_avg_xG(s1617)
s1718 = roll_avg_xG(s1718)
s1819 = roll_avg_xG(s1819)
s1920 = roll_avg_xG(s1920)

# %%
#rolling average of expected points for each team
#5 games time window
def roll_avg_xpts(df):
    
    #Dataframe of home team 
    home_df = df.groupby(['Date','HomeTeam']).sum()['HTxpts'].reset_index()
    home_df.columns = ['Date','Team','xpts']
    
    #Dataframe of away team
    away_df = df.groupby(['Date','AwayTeam']).sum()['ATxpts'].reset_index()
    away_df.columns = ['Date','Team','xpts']
    
    #Concatenation of the two dataframes and then we sort it by date ascending
    cdf = pd.concat([home_df,away_df],ignore_index=True)
    cdf = cdf.sort_values('Date',ascending=True)

    #calculation of rolling avg of xpts for each team
    cdf['ravg_xpts'] = cdf.groupby('Team')['xpts'].apply(lambda x: x.rolling(window=5,closed='left').mean())
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','HomeTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_xpts':'l5_ravg_HTxpts'},inplace=True)
    df = df.drop(['Team','xpts'],axis=1)
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','AwayTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_xpts':'l5_ravg_ATxpts'},inplace=True)
    df = df.drop(['Team','xpts'],axis=1)


    return df

# %%
s1415 = roll_avg_xpts(s1415)
s1516 = roll_avg_xpts(s1516)
s1617 = roll_avg_xpts(s1617)
s1718 = roll_avg_xpts(s1718)
s1819 = roll_avg_xpts(s1819)
s1920 = roll_avg_xpts(s1920)

# %%
#rolling average of passes exchanged within an estimated 20 yards from goal for each team
#5 games time window

def roll_avg_deep(df):
    
    #Dataframe of home team 
    home_df = df.groupby(['Date','HomeTeam']).sum()['Hdeep'].reset_index()
    home_df.columns = ['Date','Team','deep']
    
    #Dataframe of away team 
    away_df = df.groupby(['Date','AwayTeam']).sum()['Adeep'].reset_index()
    away_df.columns = ['Date','Team','deep']
    
    #Concatenation of the two dataframes and then we sort it by date ascending
    cdf = pd.concat([home_df,away_df],ignore_index=True)
    cdf = cdf.sort_values('Date',ascending=True)

    #calculation of rolling avg for each team
    cdf['ravg_deep'] = cdf.groupby('Team')['deep'].apply(lambda x: x.rolling(window=5,closed='left').mean())
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','HomeTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_deep':'l5_ravg_HTdeep'},inplace=True)
    df = df.drop(['Team','deep'],axis=1)
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','AwayTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_deep':'l5_ravg_ATdeep'},inplace=True)
    df = df.drop(['Team','deep'],axis=1)


    return df

# %%
s1415 = roll_avg_deep(s1415)
s1516 = roll_avg_deep(s1516)
s1617 = roll_avg_deep(s1617)
s1718 = roll_avg_deep(s1718)
s1819 = roll_avg_deep(s1819)
s1920 = roll_avg_deep(s1920)

# %%
#rolling average of power of pressure of each team 
#5 games time window

def roll_avg_ppda(df):
    
    #Dataframe of home team 
    home_df = df.groupby(['Date','HomeTeam']).sum()['Hppda_coef'].reset_index()
    home_df.columns = ['Date','Team','ppda']
    
    #Dataframe of away team 
    away_df = df.groupby(['Date','AwayTeam']).sum()['Appda_coef'].reset_index()
    away_df.columns = ['Date','Team','ppda']
    
    #Concatenation of the two dataframes and then we sort it by date ascending
    cdf = pd.concat([home_df,away_df],ignore_index=True)
    cdf = cdf.sort_values('Date',ascending=True)

    #calculation of rolling avg for each team
    cdf['ravg_ppda'] = cdf.groupby('Team')['ppda'].apply(lambda x: x.rolling(window=5,closed='left').mean())
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','HomeTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_ppda':'l5_ravg_HTppda'},inplace=True)
    df = df.drop(['Team','ppda'],axis=1)
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','AwayTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_ppda':'l5_ravg_ATppda'},inplace=True)
    df = df.drop(['Team','ppda'],axis=1)


    return df

# %%
s1415 = roll_avg_ppda(s1415)
s1516 = roll_avg_ppda(s1516)
s1617 = roll_avg_ppda(s1617)
s1718 = roll_avg_ppda(s1718)
s1819 = roll_avg_ppda(s1819)
s1920 = roll_avg_ppda(s1920)

# %%
#rolling average of goal scored by each team 
#time window of 5 games 
def roll_avg_gs(df):
    
    #Dataframe of home team 
    home_df = df.groupby(['Date','HomeTeam']).sum()['FTHG'].reset_index()
    home_df.columns = ['Date','Team','GS']
    
    #Dataframe of away team 
    away_df = df.groupby(['Date','AwayTeam']).sum()['FTAG'].reset_index()
    away_df.columns = ['Date','Team','GS']
    
    #Concatenation of the two dataframes and then we sort it by date ascending
    cdf = pd.concat([home_df,away_df],ignore_index=True)
    cdf = cdf.sort_values('Date',ascending=True)

    #calculation of rolling avg for each team
    cdf['ravg_gs'] = cdf.groupby('Team')['GS'].apply(lambda x: x.rolling(window=5,closed='left').mean())
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','HomeTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_gs':'l5_ravg_HTgs'},inplace=True)
    df = df.drop(['Team','GS'],axis=1)
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','AwayTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_gs':'l5_ravg_ATgs'},inplace=True)
    df = df.drop(['Team','GS'],axis=1)


    return df

# %%
s1415 = roll_avg_gs(s1415)
s1516 = roll_avg_gs(s1516)
s1617 = roll_avg_gs(s1617)
s1718 = roll_avg_gs(s1718)
s1819 = roll_avg_gs(s1819)
s1920 = roll_avg_gs(s1920)

# %%
#rolling average of goals conceded by each team 
#time window of 5 games 
def roll_avg_gc(df):
    
    #Dataframe of home team
    home_df = df.groupby(['Date','HomeTeam']).sum()['FTAG'].reset_index()
    home_df.columns = ['Date','Team','GC']
    
    #Dataframe of away team 
    away_df = df.groupby(['Date','AwayTeam']).sum()['FTHG'].reset_index()
    away_df.columns = ['Date','Team','GC']
    
    #Concatenation of the two dataframes and then we sort it by date ascending
    cdf = pd.concat([home_df,away_df],ignore_index=True)
    cdf = cdf.sort_values('Date',ascending=True)

    #calculation of rolling avg for each team
    cdf['ravg_gc'] = cdf.groupby('Team')['GC'].apply(lambda x: x.rolling(window=5,closed='left').mean())
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','HomeTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_gc':'l5_ravg_HTgc'},inplace=True)
    df = df.drop(['Team','GC'],axis=1)
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','AwayTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_gc':'l5_ravg_ATgc'},inplace=True)
    df = df.drop(['Team','GC'],axis=1)


    return df

# %%
s1415 = roll_avg_gc(s1415)
s1516 = roll_avg_gc(s1516)
s1617 = roll_avg_gc(s1617)
s1718 = roll_avg_gc(s1718)
s1819 = roll_avg_gc(s1819)
s1920 = roll_avg_gc(s1920)

# %%
#diffence between the rolling average of goals scored and conceded
def l5_tdif(df):
    
    df['l5_htdiff'] = df['l5_ravg_HTgs'] - df['l5_ravg_HTgc']
    df['l5_atdiff'] = df['l5_ravg_ATgs'] - df['l5_ravg_ATgc']
    
    return df

# %%
s1415 = l5_tdif(s1415)
s1516 = l5_tdif(s1516)
s1617 = l5_tdif(s1617)
s1718 = l5_tdif(s1718)
s1819 = l5_tdif(s1819)
s1920 = l5_tdif(s1920)

# %%
#team points
def match_point(home_team, FTR):
    if FTR == 'H':
        if home_team:
            return 3
        else:
            return 0
    elif FTR == 'A':
        if home_team:
            return 0
        else:
            return 3
    else:
        return 1

def team_points(df):
    teams = {key:[0] for key in df['HomeTeam'].unique()}
  
    for i, row in df.iterrows():
    
        teams[row['HomeTeam']].append(teams[row['HomeTeam']][-1] + match_point(home_team=True, FTR=row['FTR']))
        teams[row['AwayTeam']].append(teams[row['AwayTeam']][-1] + match_point(home_team=False, FTR=row['FTR']))
    
    df['HomeTeamPoints'] = 0
    df['AwayTeamPoints'] = 0
    
    for i, row in df.iterrows():
    
        df.at[i, 'HomeTeamPoints'] = teams[row.HomeTeam].pop(0)
        df.at[i, 'AwayTeamPoints'] = teams[row.AwayTeam].pop(0)
  
    return df

# %%
s1415 = team_points(s1415)
s1516 = team_points(s1516)
s1617 = team_points(s1617)
s1718 = team_points(s1718)
s1819 = team_points(s1819)
s1920 = team_points(s1920)

# %%
#average of team points
def match_point(home_team, FTR):
    if FTR == 'H':
        if home_team:
            return 3
        else:
            return 0
    elif FTR == 'A':
        if home_team:
            return 0
        else:
            return 3
    else:
        return 1

def avg_team_points(df):
    teams = {key:[0] for key in df['HomeTeam'].unique()}
  
    j=0
    for i, row in df.iterrows():
        
   
        
        if j==0:
            teams[row['HomeTeam']].append(teams[row['HomeTeam']][-1] + match_point(home_team=True, FTR=row['FTR']))
            teams[row['AwayTeam']].append(teams[row['AwayTeam']][-1] + match_point(home_team=False, FTR=row['FTR']))
        else:
            teams[row['HomeTeam']].append(round((teams[row['HomeTeam']][-1] + match_point(home_team=True, FTR=row['FTR']))/j,2))
            teams[row['AwayTeam']].append(round((teams[row['AwayTeam']][-1] + match_point(home_team=False, FTR=row['FTR']))/j,2))
    
        if (i % 9) == 0:
            j = j + 1
    
    df['avgHTP'] = 0
    df['avgATP'] = 0
    
    for i, row in df.iterrows():
    
        df.at[i, 'avgHTP'] = teams[row.HomeTeam].pop(0)
        df.at[i, 'avgATP'] = teams[row.AwayTeam].pop(0)
  
    return df

# %%
s1415 = avg_team_points(s1415)
s1516 = avg_team_points(s1516)
s1617 = avg_team_points(s1617)
s1718 = avg_team_points(s1718)
s1819 = avg_team_points(s1819)
s1920 = avg_team_points(s1920)

# %%
#rolling average of points, time window = 5 
def roll_avg_points(df):
    
    #Dataframe of home team matches
    home_df = df.groupby(['Date','HomeTeam']).sum()['HomeTeamPoints'].reset_index()
    home_df.columns = ['Date','Team','P']
    
    #Dataframe of away team matches
    away_df = df.groupby(['Date','AwayTeam']).sum()['AwayTeamPoints'].reset_index()
    away_df.columns = ['Date','Team','P']
    
    #Concatenation of the two dataframes and then we sort it by date ascending
    cdf = pd.concat([home_df,away_df],ignore_index=True)
    cdf = cdf.sort_values('Date',ascending=True)

    #calculation of rolling avg for each team
    cdf['ravg_p'] = cdf.groupby('Team')['P'].apply(lambda x: x.rolling(window=5,closed='left').mean())
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','HomeTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_p':'l5_ravg_HTp'},inplace=True)
    df = df.drop(['Team','P'],axis=1)
    
    df = pd.merge(df,cdf,how='inner',left_on=['Date','AwayTeam'],right_on=['Date','Team'])
    df.rename(columns={'ravg_p':'l3_ravg_ATp'},inplace=True)
    df = df.drop(['Team','P'],axis=1)


    return df

# %%
s1415 = roll_avg_points(s1415)
s1516 = roll_avg_points(s1516)
s1617 = roll_avg_points(s1617)
s1718 = roll_avg_points(s1718)
s1819 = roll_avg_points(s1819)
s1920 = roll_avg_points(s1920)

# %%
#difference of points between the home and away team
def diff_points(df):
    
    df['diff_points'] = df['HomeTeamPoints'] - df['AwayTeamPoints']
    
    return df

# %%
s1415 = diff_points(s1415)
s1516 = diff_points(s1516)
s1617 = diff_points(s1617)
s1718 = diff_points(s1718)
s1819 = diff_points(s1819)
s1920 = diff_points(s1920)

# %%
#difference between the ratings of home and away team
def diff_stats(df):
    
    df['diff_ATT'] = df['HTatt_S'] - df['ATatt_S']
    df['diff_MID'] = df['HTmid_S'] - df['ATmid_S']
    df['diff_DEF'] = df['HTdef_S'] - df['ATdef_S']
    df['diff_OVA'] = df['HTOVA_S'] - df['ATOVA_S']
    
    return df

# %%
s1415 = diff_stats(s1415)
s1516 = diff_stats(s1516)
s1617 = diff_stats(s1617)
s1718 = diff_stats(s1718)
s1819 = diff_stats(s1819)
s1920 = diff_stats(s1920)

# %%
df = pd.concat([s1415, s1516, s1617, s1718, s1819, s1920]).reset_index(drop=True)

# %%
#we are dropping the collumns that are not available to us before the game
df = df.drop(['HS','AS','HST','AST','HC','AC','HF','AF','HxG','AxG',
              'Hdeep','Adeep',],axis=1)

# %%
df.to_csv("premier_league.csv")
